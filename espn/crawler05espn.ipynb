# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import random
from selenium.common.exceptions import TimeoutException

url = 'http://insider.espn.com/nba/hollinger/statistics/_/page/'

try:
    # 設置 ChromeOptions 並啟動 Chrome
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')  # 無頭模式不會跳出視窗
    chrome = webdriver.Chrome(options=options)  # 將 options 傳入 Chrome 瀏覽器

    chrome.set_page_load_timeout(30)  # 將加載超時時間設置為 30 秒

    for i in range(1, 9):  # 假設有 8 頁
        _url = url + str(i) + '/year/2024'
        print("Fetching URL:", _url)
        
        try:
            chrome.get(_url)  # 加載網頁
        except TimeoutException:
            chrome.execute_script("window.stop();")  # 超時後停止加載
            print(f"Stopped loading {_url}")
            continue
        
        # 使用 BeautifulSoup 解析頁面
        soup = BeautifulSoup(chrome.page_source, 'html5lib')
        
        # 檢查 tbody 是否存在
        tbody = soup.find('tbody')
        if not tbody:
            print("No data found on this page:", _url)
            continue
        
        trs = tbody.find_all('tr')
        for tr in trs:
            tds = list(tr.children)
            if len(tds) < 2:
                continue
            
            rk = tds[0].text.strip()
            # 過濾表頭或不正確的行
            if rk == 'RK':
                continue
            
            name = tds[1].text.strip()
            per = tds[11].text.strip() if len(tds) > 11 else 'N/A'  # 確保第 12 個欄位存在
            print('%s : %s' % (name, per))
        
        # 隨機等待，防止過於頻繁的請求
        wait = random.randint(2, 6)
        print('Wait time: %d seconds' % wait)
        time.sleep(wait)
    
finally:
    chrome.quit()  # 確保最後關閉瀏覽器
# Out:
# Fetching URL: http://insider.espn.com/nba/hollinger/statistics/_/page/1/year/2024
# Stopped loading http://insider.espn.com/nba/hollinger/statistics/_/page/1/year/2024
# Fetching URL: http://insider.espn.com/nba/hollinger/statistics/_/page/2/year/2024
# Marvin Bagley III, DET/WSH : 19.62
# Myles Turner, IND : 19.53
# Paul George, LAC : 19.50
# Rudy Gobert, MIN : 19.49
# Ivica Zubac, LAC : 19.47
# Jonathan Isaac, ORL : 19.37
# Jalen Williams, OKC : 19.27
# Deandre Ayton, POR : 19.13
# Isaiah Hartenstein, NY : 19.05
# Julius Randle, NY : 19.05
# Jakob Poeltl, TOR : 19.03
# Karl-Anthony Towns, MIN : 18.99
# Jalen Duren, DET : 18.89
# Jaylen Brown, BOS : 18.85
# Nic Claxton, BKN : 18.83
# James Harden, LAC : 18.71
# Desmond Bane, MEM : 18.65
# Kevin Love, MIA : 18.63
# Brandon Ingram, NO : 18.35
# Dereck Lively II, DAL : 18.30
# Amen Thompson, HOU : 18.30
# Walker Kessler, UTAH : 18.10
# CJ McCollum, NO : 18.05
# Goga Bitadze, ORL : 17.93
# Dejounte Murray, ATL : 17.93
# Nikola Vucevic, CHI : 17.86
# Franz Wagner, ORL : 17.74
# Bobby Portis, MIL : 17.65
# John Collins, UTAH : 17.63
# Jaren Jackson Jr., MEM : 17.59
# Jusuf Nurkic, PHX : 17.57
# Paul Reed, PHI : 17.56
# Kelly Olynyk, UTAH/TOR : 17.50
# Paolo Banchero, ORL : 17.49
# Terry Rozier, CHA/MIA : 17.43
# Cade Cunningham, DET : 17.23
# Malcolm Brogdon, POR : 17.19
# Khris Middleton, MIL : 17.16
# Jonathan Kuminga, GS : 17.14
# Derrick White, BOS : 17.10
# Onyeka Okongwu, ATL : 17.04
# Aaron Gordon, DEN : 16.93
# Fred VanVleet, HOU : 16.87
# Immanuel Quickley, NY/TOR : 16.87
# Cam Whitmore, HOU : 16.80
# Nick Richards, CHA : 16.79
# Josh Giddey, OKC : 16.78
# Tyus Jones, WSH : 16.65
# Tobias Harris, PHI : 16.64
# Obi Toppin, IND : 16.63
# Wait time: 5 seconds
# Fetching URL: http://insider.espn.com/nba/hollinger/statistics/_/page/3/year/2024
# Stopped loading http://insider.espn.com/nba/hollinger/statistics/_/page/3/year/2024
# Fetching URL: http://insider.espn.com/nba/hollinger/statistics/_/page/4/year/2024
# Stopped loading http://insider.espn.com/nba/hollinger/statistics/_/page/4/year/2024
# Fetching URL: http://insider.espn.com/nba/hollinger/statistics/_/page/5/year/2024
# Brandon Miller, CHA : 13.14
# Sam Hauser, BOS : 13.12
# Jabari Walker, POR : 13.09
# Brandin Podziemski, GS : 13.07
# Alec Burks, DET/NY : 12.99
# Jaime Jaquez Jr., MIA : 12.99
# Corey Kispert, WSH : 12.97
# Aaron Nesmith, IND : 12.97
# Ausar Thompson, DET : 12.95
# Gordon Hayward, CHA/OKC : 12.93
# Cameron Payne, MIL/PHI : 12.92
# Vince Williams Jr., MEM : 12.90
# Nikola Jovic, MIA : 12.90
# Kris Dunn, UTAH : 12.89
# Andrew Wiggins, GS : 12.89
# OG Anunoby, TOR/NY : 12.88
# De'Andre Hunter, ATL : 12.87
# Oshae Brissett, BOS : 12.87
# Naji Marshall, NO : 12.86
# Jordan Clarkson, UTAH : 12.80
# Jaylin Williams, OKC : 12.80
# Kyle Anderson, MIN : 12.78
# Markelle Fultz, ORL : 12.76
# Bojan Bogdanovic, DET/NY : 12.74
# Jake LaRavia, MEM : 12.70
# Jordan Goodwin, PHX/MEM : 12.68
# Jose Alvarado, NO : 12.64
# Jaden Ivey, DET : 12.57
# Kevin Huerter, SAC : 12.54
# Zeke Nnaji, DEN : 12.50
# Christian Wood, LAL : 12.43
# Xavier Tillman, MEM/BOS : 12.36
# Duncan Robinson, MIA : 12.32
# P.J. Washington, CHA/DAL : 12.27
# Simone Fontecchio, UTAH/DET : 12.25
# Christian Braun, DEN : 12.20
# Jordan Poole, WSH : 12.19
# Tim Hardaway Jr., DAL : 12.18
# Gary Trent Jr., TOR : 12.18
# Dyson Daniels, NO : 12.13
# Terance Mann, LAC : 12.12
# Cason Wallace, OKC : 12.10
# Josh Okogie, PHX : 12.07
# Keon Ellis, SAC : 12.06
# Harrison Barnes, SAC : 12.04
# Malachi Flynn, TOR/NY/DET : 12.03
# Trey Lyles, SAC : 12.00
# Kenrich Williams, OKC : 11.97
# Marcus Smart, MEM : 11.95
# Trey Jemison, WSH/MEM : 11.93
# Wait time: 5 seconds
# Fetching URL: http://insider.espn.com/nba/hollinger/statistics/_/page/6/year/2024
# Marcus Sasser, DET : 11.90
# Peyton Watson, DEN : 11.88
# Josh Hart, NY : 11.88
# Taylor Hendricks, UTAH : 11.86
# Reggie Jackson, DEN : 11.86
# Spencer Dinwiddie, BKN/LAL : 11.84
# Derrick Jones Jr., DAL : 11.83
# Max Strus, CLE : 11.76
# Bruce Brown, IND/TOR : 11.72
# Davis Bertans, OKC/CHA : 11.70
# Jarred Vanderbilt, LAL : 11.68
# Patrick Beverley, PHI/MIL : 11.67
# Aaron Holiday, HOU : 11.61
# Keita Bates-Diop, PHX/BKN : 11.58
# Josh Richardson, MIA : 11.57
# Isaac Okoro, CLE : 11.53
# Jeremy Sochan, SA : 11.50
# Shaedon Sharpe, POR : 11.48
# John Konchar, MEM : 11.47
# Andrew Nembhard, IND : 11.44
# Jeff Green, HOU : 11.38
# Isaiah Stewart, DET : 11.38
# Jaden Hardy, DAL : 11.37
# Cedi Osman, SA : 11.35
# Jacob Gilyard, MEM/BKN : 11.22
# Haywood Highsmith, MIA : 11.22
# Royce O'Neale, BKN/PHX : 11.21
# Luguentz Dort, OKC : 11.14
# Patrick Williams, CHI : 11.08
# Nickeil Alexander-Walker, MIN : 11.04
# Kyle Lowry, MIA/PHI : 11.02
# Bones Hyland, LAC : 10.97
# Jericho Sims, NY : 10.97
# Eric Gordon, PHX : 10.95
# Torrey Craig, CHI : 10.93
# Jalen Wilson, BKN : 10.93
# Caleb Martin, MIA : 10.91
# Vasilije Micic, OKC/CHA : 10.83
# Jaden Springer, PHI/BOS : 10.77
# Kentavious Caldwell-Pope, DEN : 10.76
# Grant Williams, DAL/CHA : 10.73
# Julian Champagnie, SA : 10.73
# Toumani Camara, POR : 10.71
# Joe Ingles, ORL : 10.68
# AJ Green, MIL : 10.62
# Landry Shamet, WSH : 10.60
# Killian Hayes, DET : 10.59
# Keyonte George, UTAH : 10.50
# Matisse Thybulle, POR : 10.49
# Malik Beasley, MIL : 10.44
# Wait time: 2 seconds
# Fetching URL: http://insider.espn.com/nba/hollinger/statistics/_/page/7/year/2024
# Stopped loading http://insider.espn.com/nba/hollinger/statistics/_/page/7/year/2024
# Fetching URL: http://insider.espn.com/nba/hollinger/statistics/_/page/8/year/2024
# No data found on this page: http://insider.espn.com/nba/hollinger/statistics/_/page/8/year/2024
